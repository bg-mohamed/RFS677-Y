# %%
import pandas as pd 
import numpy as np 
from pandas_datareader import data as pdr
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.stats.api as sms
import statsmodels.api as sm
from statsmodels.tsa.stattools import kpss
from statsmodels.compat import lzip
from scipy import stats
import statsmodels.stats.diagnostic as sms
import statsmodels.formula.api as smf
from statsmodels.stats.diagnostic import acorr_breusch_godfrey
from statsmodels.stats.diagnostic import het_breuschpagan

# %%
#10 actifs choisis parmi les TOP 30 components du DowJones Industrial index
df = yf.download(['VZ', 'GS', 'KO', 'JNJ','INTC','V', 'MCD', 'CAT', 'CVX', 'WMT','^DJI'], start="2010-01-01", end="2021-01-01", interval = '1mo')
df=df['Adj Close'] 
df=df.dropna()
df=df.reset_index()
# Out:
# [*********************100%***********************]  11 of 11 completed

# %%
#Facteurs
df[['SMB','HML', 'RMW', 'CMA','RF']] = pd.read_excel("data/FamaFrench.xlsx", usecols = "B:F", skiprows = 559, nrows = 132, index_col= None, dtype=np.float64)
df = df.set_index(['Date'])

# %%
df.head()
# Out:
#                   CAT        CVX          GS       INTC        JNJ         KO  \
# Date
# 2010-01-01  38.176113  45.795624  125.494270  13.726318  44.716648  19.115171
# 2010-02-01  41.975620  45.909939  131.932663  14.525841  44.816246  18.576071
# 2010-03-01  46.243088  48.612293  144.305435  15.897274  46.736115  19.379435
# 2010-04-01  50.098503  52.208694  122.798691  16.289536  46.090996  18.987429
# 2010-05-01  44.984196  47.355808  122.003708  15.276789  41.790127  18.259199
#
#                   MCD          V         VZ        WMT          ^DJI   SMB  \
# Date
# 2010-01-01  44.686398  18.902119  16.055996  40.670963  10067.330078  1.48
# 2010-02-01  45.702812  19.651011  16.016777  41.158127  10325.259766  1.80
# 2010-03-01  48.163021  21.007515  17.173878  42.322769  10856.629883  4.99
# 2010-04-01  50.956638  20.822891  16.000162  41.060947  11008.610352  0.09
# 2010-05-01  48.271301  16.722010  15.471686  38.703243  10136.629883 -2.46
#
#              HML   RMW   CMA    RF
# Date
# 2010-01-01  3.19 -0.40  1.43  0.00
# 2010-02-01  2.11 -0.67  1.69  0.01
# 2010-03-01  2.91  0.88  1.69  0.01
# 2010-04-01 -2.39  1.24 -0.19  0.01
# 2010-05-01 -4.52 -0.31 -1.50  0.01

# %% [markdown]
# ### <span style="color:red"> 1.Transformation des variables </span>

# %% [markdown]
# #### 1.a Transformation des indices boursiers en rendement

# %%
def rendement(x):
    r = ((x - x.shift(1))/(x.shift(1)))*100
    return (r)

# %%
skip = ['RF','SMB','HML', 'RMW', 'CMA'] 
cols = df.columns[~df.columns.isin(skip)]
for i in cols:
    df[i] = rendement(df[i])
df=df.dropna()

# %% [markdown]
# ### <span style="color:red">2.Création des variables dépendantes </span>

# %%
plt.rcParams['figure.figsize'] = (10, 7)
plt.rcParams['axes.grid'] = False
plt.rcParams['legend.loc'] = 'best'

# %% [markdown]
# #### 2.1 Test de stationnarité du RF

# %%
df['RF'].plot();

# %%
def kpss_test(series, **kw):
    statistic, p_value, n_lags, critical_values= kpss(series, **kw)
    print(f'KPSS statistic: {statistic}')
    print(f'p_value: {p_value}')
    print(f'num lags: {n_lags}')
    print(f'Critical values:')
    for key, value in critical_values.items():
        print(f' {key} : {value}')
    print(f'Result: the series is {"not " if p_value < 0.05 else ""}stationary')

# %%
#Test de stationnarité 
kpss_results = {}
print(f'RF')
kpss_results = kpss_test(df['RF'])
# Out:
# RF
# KPSS statistic: 0.5352681460273225
# p_value: 0.03372339053438682
# num lags: 13
# Critical values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# Result: the series is not stationary
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1875: FutureWarning: The behavior of using nlags=None will change in release 0.13.Currently nlags=None is the same as nlags="legacy", and so a sample-size lag length is used. After the next release, the default will change to be the same as nlags="auto" which uses an automatic lag length selection method. To silence this warning, either use "auto" or "legacy"
#   warnings.warn(msg, FutureWarning)

# %%
df['RF'] = df['RF'].diff()
df= df.dropna()

# %%
#Test de stationnarité 
kpss_results = {}
print(f'RF')
kpss_results = kpss_test(df['RF'])
# Out:
# RF
# KPSS statistic: 0.13904404517450664
# p_value: 0.1
# num lags: 13
# Critical values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# Result: the series is stationary
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1875: FutureWarning: The behavior of using nlags=None will change in release 0.13.Currently nlags=None is the same as nlags="legacy", and so a sample-size lag length is used. After the next release, the default will change to be the same as nlags="auto" which uses an automatic lag length selection method. To silence this warning, either use "auto" or "legacy"
#   warnings.warn(msg, FutureWarning)
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %% [markdown]
# #### 2.2 Création des variables dépendantes

# %% [markdown]
# #### `y = Le rendement d'un actif (cours boursier en l'occurence) - L'actif sans risque RF`

# %%
pd.options.mode.chained_assignment = None

# %%
for i in df[cols].columns:
    df[i]=df[i]-df['RF']

y = df[cols].drop("^DJI",1)

# %% [markdown]
# ### <span style="color:red">3.Création de la variable indépendante</span>
#
# #### `X= L'indice du DowJones - L'actif sans risque RF`

# %%
df['p_risque']=df['^DJI']-df['RF']

# %%
X = df['p_risque']

# %% [markdown]
# ### <span style="color:red">4.Tests de stationnarité</span>
#
# #### 4.1 La variable indépendante

# %%
plt.rcParams['figure.figsize'] = (10, 7)
plt.rcParams['axes.grid'] = False
plt.rcParams['legend.loc'] = 'best'

# %%
X.plot()
plt.title('Index')
plt.xlabel('Date')
plt.ylabel('P_RISQUE')
plt.legend(loc='best', bbox_to_anchor=(1, 0.5))
plt.show();

# %%
def kpss_test(series, **kw):
    statistic, p_value, n_lags, critical_values= kpss(series, **kw)
    print(f'KPSS statistic: {statistic}')
    print(f'p_value: {p_value}')
    print(f'num lags: {n_lags}')
    print(f'Critical values:')
    for key, value in critical_values.items():
        print(f' {key} : {value}')
    print(f'Result: the series is {"not " if p_value < 0.05 else ""}stationary')

# %%
#Test de stationnarité 
kpss_results = {}
print(f'X')
kpss_results = kpss_test(X)
# Out:
# X
# KPSS statistic: 0.05866430346499228
# p_value: 0.1
# num lags: 13
# Critical values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# Result: the series is stationary
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1875: FutureWarning: The behavior of using nlags=None will change in release 0.13.Currently nlags=None is the same as nlags="legacy", and so a sample-size lag length is used. After the next release, the default will change to be the same as nlags="auto" which uses an automatic lag length selection method. To silence this warning, either use "auto" or "legacy"
#   warnings.warn(msg, FutureWarning)
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %% [markdown]
# #### 4.2 Les variables dépendantes

# %%
y.plot()
plt.title('Index')
plt.xlabel('Date')
plt.ylabel('Rendement')
plt.legend(loc='best', bbox_to_anchor=(1, 0.5), title="Actions")
plt.show();

# %%
#Test de stationnarité
kpss_results = {}
for i in y:
    print(f'{i}')
    kpss_results[i] = kpss_test(y[i])
# Out:
# CAT
# KPSS statistic: 0.09019623270141801
# p_value: 0.1
# num lags: 13
# Critical values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# Result: the series is stationary
# CVX
# KPSS statistic: 0.23148828987510306
# p_value: 0.1
# num lags: 13
# Critical values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# Result: the series is stationary
# GS
# KPSS statistic: 0.09366916184830537
# p_value: 0.1
# num lags: 13
# Critical values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# Result: the series is stationary
# INTC
# KPSS statistic: 0.05975126755062814
# p_value: 0.1
# num lags: 13
# Critical values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# Result: the series is stationary
# JNJ
# KPSS statistic: 0.0747106610368449
# p_value: 0.1
# num lags: 13
# Critical values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# Result: the series is stationary
# KO
# KPSS statistic: 0.16150739598540917
# p_value: 0.1
# num lags: 13
# Critical values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# Result: the series is stationary
# MCD
# KPSS statistic: 0.0823001866889567
# p_value: 0.1
# num lags: 13
# Critical values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# Result: the series is stationary
# V
# KPSS statistic: 0.07708484256571387
# p_value: 0.1
# num lags: 13
# Critical values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# Result: the series is stationary
# VZ
# KPSS statistic: 0.31990982000408213
# p_value: 0.1
# num lags: 13
# Critical values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# Result: the series is stationary
# WMT
# KPSS statistic: 0.18886103970348286
# p_value: 0.1
# num lags: 13
# Critical values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# Result: the series is stationary
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1875: FutureWarning: The behavior of using nlags=None will change in release 0.13.Currently nlags=None is the same as nlags="legacy", and so a sample-size lag length is used. After the next release, the default will change to be the same as nlags="auto" which uses an automatic lag length selection method. To silence this warning, either use "auto" or "legacy"
#   warnings.warn(msg, FutureWarning)
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %% [markdown]
# ### <span style="color:red">5.Tests de normalité</span>
#
# #### 5.1 La variable indépendante X

# %%
X.plot.density();

# %%
X.plot.box();

# %% [markdown]
# [![bxplt-inter.png](https://i.postimg.cc/Jz1YdZcx/bxplt-inter.png)](https://postimg.cc/XpzgrZPB)

# %%
print('QQ plot du p_risque')
sm.qqplot(X, line='s')
plt.show();
# Out:
# QQ plot du p_risque

# %%
#Test de normalité (Shapiro-Wilk)
#H0 : distribution normale
#HA : pas de distribution normale
p_value = 0.05
a,b= stats.shapiro(X)
print ("Statistiques", a, "p_value", b)
if b < p_value:
    print(f"L'hypothèse nulle H0 peut être rejetée et la série p_risque ne présente pas de distribution normale")
else:
    print(f"L'hypothèse nulle H0 ne peut être rejetée et la série p_risque présente une distribution normale")
# Out:
# Statistiques 0.9737986326217651 p_value 0.012762974016368389
# L'hypothèse nulle H0 peut être rejetée et la série p_risque ne présente pas de distribution normale

# %% [markdown]
#  #### 5.2 Les variables dépendantes y

# %%
y.plot.density();

# %%
y.boxplot();

# %%
for i,val in enumerate(y):
    print('QQ plot de', val)
    sm.qqplot(y[val], line='s')
    plt.show();
# Out:
# QQ plot de CAT
# QQ plot de CVX
# QQ plot de GS
# QQ plot de INTC
# QQ plot de JNJ
# QQ plot de KO
# QQ plot de MCD
# QQ plot de V
# QQ plot de VZ
# QQ plot de WMT

# %%
#Test de normalité (Shapiro-Wilk)
#H0 : distribution normale
#HA : pas de distribution normale
p_value = 0.05
for i in y :
    print(i)
    a,b= stats.shapiro(y[[i]])
    print ("Statistiques", a, "p_value", b)
    if b < p_value:
        print(f"L'hypothèse nulle H0 peut être rejetée et la série {i} ne présente pas de distribution normale")
    else:
        print(f"L'hypothèse nulle H0 ne peut être rejetée et la série {i} présente une distribution normale")
# Out:
# CAT
# Statistiques 0.990478515625 p_value 0.5176470875740051
# L'hypothèse nulle H0 ne peut être rejetée et la série CAT présente une distribution normale
# CVX
# Statistiques 0.9651925563812256 p_value 0.002036865334957838
# L'hypothèse nulle H0 peut être rejetée et la série CVX ne présente pas de distribution normale
# GS
# Statistiques 0.9903140068054199 p_value 0.5022740364074707
# L'hypothèse nulle H0 ne peut être rejetée et la série GS présente une distribution normale
# INTC
# Statistiques 0.9911571145057678 p_value 0.5834054350852966
# L'hypothèse nulle H0 ne peut être rejetée et la série INTC présente une distribution normale
# JNJ
# Statistiques 0.989189863204956 p_value 0.4046376049518585
# L'hypothèse nulle H0 ne peut être rejetée et la série JNJ présente une distribution normale
# KO
# Statistiques 0.9607104659080505 p_value 0.0008306278032250702
# L'hypothèse nulle H0 peut être rejetée et la série KO ne présente pas de distribution normale
# MCD
# Statistiques 0.9801103472709656 p_value 0.05334867164492607
# L'hypothèse nulle H0 ne peut être rejetée et la série MCD présente une distribution normale
# V
# Statistiques 0.981655478477478 p_value 0.07617698609828949
# L'hypothèse nulle H0 ne peut être rejetée et la série V présente une distribution normale
# VZ
# Statistiques 0.990888774394989 p_value 0.556991696357727
# L'hypothèse nulle H0 ne peut être rejetée et la série VZ présente une distribution normale
# WMT
# Statistiques 0.9906952381134033 p_value 0.5382605195045471
# L'hypothèse nulle H0 ne peut être rejetée et la série WMT présente une distribution normale

# %% [markdown]
# ### <span style="color:red">6.Estimation du modèle</span>

# %% [markdown]
# [![level-level.png](https://i.postimg.cc/V666gLxY/level-level.png)](https://postimg.cc/jWptdKq9)

# %%
Z = pd.concat ([y,X],1)

# %%
skip = ['p_risque'] 
cols = Z.columns[~Z.columns.isin(skip)]
liste = []
alpha = []
pval = []
rsq = []
resid = []
Mco = []
for i in cols:
    mco = smf.ols(i+'~p_risque',data = Z).fit()
    liste.append(mco.summary())
    alpha.append(mco.params.loc['Intercept'])
    pval.append(mco.pvalues)
    rsq.append(mco.rsquared_adj)
    resid.append(sum(mco.resid))
    Mco.append(mco)

# %%
#Résultats de la régression
for l in liste:
    print(f'{l}\n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CAT   R-squared:                       0.416
# Model:                            OLS   Adj. R-squared:                  0.411
# Method:                 Least Squares   F-statistic:                     91.01
# Date:                Fri, 04 Jun 2021   Prob (F-statistic):           1.27e-16
# Time:                        19:22:38   Log-Likelihood:                -417.78
# No. Observations:                 130   AIC:                             839.6
# Df Residuals:                     128   BIC:                             845.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2680      0.546      0.491      0.624      -0.812       1.348
# p_risque       1.2680      0.133      9.540      0.000       1.005       1.531
# ==============================================================================
# Omnibus:                        0.078   Durbin-Watson:                   2.319
# Prob(Omnibus):                  0.962   Jarque-Bera (JB):                0.224
# Skew:                           0.031   Prob(JB):                        0.894
# Kurtosis:                       2.806   Cond. No.                         4.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CVX   R-squared:                       0.580
# Model:                            OLS   Adj. R-squared:                  0.576
# Method:                 Least Squares   F-statistic:                     176.6
# Date:                Fri, 04 Jun 2021   Prob (F-statistic):           7.42e-26
# Time:                        19:22:38   Log-Likelihood:                -378.78
# No. Observations:                 130   AIC:                             761.6
# Df Residuals:                     128   BIC:                             767.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5224      0.404     -1.292      0.199      -1.322       0.278
# p_risque       1.3084      0.098     13.287      0.000       1.114       1.503
# ==============================================================================
# Omnibus:                        0.332   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.847   Jarque-Bera (JB):                0.089
# Skew:                          -0.029   Prob(JB):                        0.956
# Kurtosis:                       3.114   Cond. No.                         4.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     GS   R-squared:                       0.540
# Model:                            OLS   Adj. R-squared:                  0.536
# Method:                 Least Squares   F-statistic:                     150.1
# Date:                Fri, 04 Jun 2021   Prob (F-statistic):           2.61e-23
# Time:                        19:22:38   Log-Likelihood:                -410.05
# No. Observations:                 130   AIC:                             824.1
# Df Residuals:                     128   BIC:                             829.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5391      0.514     -1.048      0.297      -1.557       0.479
# p_risque       1.5343      0.125     12.250      0.000       1.286       1.782
# ==============================================================================
# Omnibus:                        4.802   Durbin-Watson:                   2.051
# Prob(Omnibus):                  0.091   Jarque-Bera (JB):                6.197
# Skew:                           0.126   Prob(JB):                       0.0451
# Kurtosis:                       4.040   Cond. No.                         4.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   INTC   R-squared:                       0.281
# Model:                            OLS   Adj. R-squared:                  0.276
# Method:                 Least Squares   F-statistic:                     50.11
# Date:                Fri, 04 Jun 2021   Prob (F-statistic):           8.56e-11
# Time:                        19:22:38   Log-Likelihood:                -412.16
# No. Observations:                 130   AIC:                             828.3
# Df Residuals:                     128   BIC:                             834.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3469      0.523      0.664      0.508      -0.687       1.381
# p_risque       0.9011      0.127      7.079      0.000       0.649       1.153
# ==============================================================================
# Omnibus:                        5.371   Durbin-Watson:                   1.911
# Prob(Omnibus):                  0.068   Jarque-Bera (JB):                6.164
# Skew:                          -0.250   Prob(JB):                       0.0459
# Kurtosis:                       3.943   Cond. No.                         4.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    JNJ   R-squared:                       0.393
# Model:                            OLS   Adj. R-squared:                  0.389
# Method:                 Least Squares   F-statistic:                     82.96
# Date:                Fri, 04 Jun 2021   Prob (F-statistic):           1.44e-15
# Time:                        19:22:38   Log-Likelihood:                -344.40
# No. Observations:                 130   AIC:                             692.8
# Df Residuals:                     128   BIC:                             698.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4236      0.310      1.365      0.175      -0.191       1.038
# p_risque       0.6885      0.076      9.108      0.000       0.539       0.838
# ==============================================================================
# Omnibus:                        0.578   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.749   Jarque-Bera (JB):                0.691
# Skew:                           0.023   Prob(JB):                        0.708
# Kurtosis:                       2.646   Cond. No.                         4.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     KO   R-squared:                       0.322
# Model:                            OLS   Adj. R-squared:                  0.317
# Method:                 Least Squares   F-statistic:                     60.74
# Date:                Fri, 04 Jun 2021   Prob (F-statistic):           1.96e-12
# Time:                        19:22:38   Log-Likelihood:                -346.17
# No. Observations:                 130   AIC:                             696.3
# Df Residuals:                     128   BIC:                             702.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3708      0.315      1.178      0.241      -0.252       0.993
# p_risque       0.5972      0.077      7.793      0.000       0.446       0.749
# ==============================================================================
# Omnibus:                        5.296   Durbin-Watson:                   2.130
# Prob(Omnibus):                  0.071   Jarque-Bera (JB):                5.339
# Skew:                          -0.493   Prob(JB):                       0.0693
# Kurtosis:                       2.879   Cond. No.                         4.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    MCD   R-squared:                       0.295
# Model:                            OLS   Adj. R-squared:                  0.290
# Method:                 Least Squares   F-statistic:                     53.64
# Date:                Fri, 04 Jun 2021   Prob (F-statistic):           2.38e-11
# Time:                        19:22:38   Log-Likelihood:                -350.28
# No. Observations:                 130   AIC:                             704.6
# Df Residuals:                     128   BIC:                             710.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7457      0.325      2.296      0.023       0.103       1.388
# p_risque       0.5792      0.079      7.324      0.000       0.423       0.736
# ==============================================================================
# Omnibus:                        0.464   Durbin-Watson:                   1.669
# Prob(Omnibus):                  0.793   Jarque-Bera (JB):                0.616
# Skew:                           0.101   Prob(JB):                        0.735
# Kurtosis:                       2.729   Cond. No.                         4.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      V   R-squared:                       0.457
# Model:                            OLS   Adj. R-squared:                  0.453
# Method:                 Least Squares   F-statistic:                     107.8
# Date:                Fri, 04 Jun 2021   Prob (F-statistic):           1.09e-18
# Time:                        19:22:38   Log-Likelihood:                -364.65
# No. Observations:                 130   AIC:                             733.3
# Df Residuals:                     128   BIC:                             739.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.1724      0.363      3.232      0.002       0.455       1.890
# p_risque       0.9169      0.088     10.380      0.000       0.742       1.092
# ==============================================================================
# Omnibus:                       10.032   Durbin-Watson:                   1.947
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):               16.216
# Skew:                          -0.344   Prob(JB):                     0.000301
# Kurtosis:                       4.588   Cond. No.                         4.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     VZ   R-squared:                       0.143
# Model:                            OLS   Adj. R-squared:                  0.136
# Method:                 Least Squares   F-statistic:                     21.32
# Date:                Fri, 04 Jun 2021   Prob (F-statistic):           9.33e-06
# Time:                        19:22:38   Log-Likelihood:                -376.32
# No. Observations:                 130   AIC:                             756.6
# Df Residuals:                     128   BIC:                             762.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6884      0.397      1.735      0.085      -0.097       1.474
# p_risque       0.4462      0.097      4.617      0.000       0.255       0.637
# ==============================================================================
# Omnibus:                        1.961   Durbin-Watson:                   2.322
# Prob(Omnibus):                  0.375   Jarque-Bera (JB):                1.484
# Skew:                          -0.027   Prob(JB):                        0.476
# Kurtosis:                       2.479   Cond. No.                         4.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    WMT   R-squared:                       0.137
# Model:                            OLS   Adj. R-squared:                  0.131
# Method:                 Least Squares   F-statistic:                     20.39
# Date:                Fri, 04 Jun 2021   Prob (F-statistic):           1.42e-05
# Time:                        19:22:38   Log-Likelihood:                -381.31
# No. Observations:                 130   AIC:                             766.6
# Df Residuals:                     128   BIC:                             772.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6617      0.412      1.605      0.111      -0.154       1.477
# p_risque       0.4534      0.100      4.516      0.000       0.255       0.652
# ==============================================================================
# Omnibus:                        8.259   Durbin-Watson:                   2.070
# Prob(Omnibus):                  0.016   Jarque-Bera (JB):               16.866
# Skew:                           0.002   Prob(JB):                     0.000218
# Kurtosis:                       4.765   Cond. No.                         4.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# **Analyse des résultats de l'action CAT "CATERPILLAR"**
#
# - Le **R²** est de 41.6 % qui est un score assez moyen
# - Le p_risque affecte significativement la variable CAT avec une **p-value (P>|t|)** < 0.05 et une **t (coef/std err)** assez élevèe.
# - **Omnibus** décrit la normalité de la distribution des biais combinant les valeurs skew/kurtosis, 0.078 est une distribution pseudo-normale.
# - **Prob(Omnibus)** est la probabilité que les biais auront une distribution normale, 1 correspondrait une distribution normale, ici 0.962 est une probabilité de distribution pseudo-normale.
# - **Skew** la mesure de symétrie des donnés, 0 serait une symètrie parfaite. **Kurtosis** est la mesure d'aplatissement des données plottées,un Kurtosis important implique un nombre réduit d'outliers.
# - **Durbin-Watson** est la mesure d'homoscédasticité.

# %% [markdown]
# [![level-level2.png](https://i.postimg.cc/sfbYMtWB/level-level2.png)](https://postimg.cc/rzC0bZQc)

# %% [markdown]
# ### <span style="color:red">7. Vérification des hypothèses </span>

# %% [markdown]
# [![hyp.png](https://i.postimg.cc/sXDBLJhC/hyp.png)](https://postimg.cc/nsgcjB23)

# %% [markdown]
# #### 7.1 Colinéarité

# %% [markdown]
# En Régression linéaire simple, il y a juste une variable, donc la colinéarité n'existe pas.

# %% [markdown]
# #### 7.2 Calcul du Biais

# %%
resid1=pd.DataFrame(resid, index = cols, columns = ['Biais'])
resid1 /= len(y)
resid1
# Out:
#              Biais
# CAT   6.148928e-16
# CVX  -1.913000e-16
# GS   -2.732857e-17
# INTC  4.235928e-16
# JNJ   2.459571e-16
# KO    3.552714e-16
# MCD   4.953303e-16
# V     6.080606e-16
# VZ    3.279428e-16
# WMT   2.117964e-16

# %% [markdown]
# Des valeurs très proches de zéro !

# %%
resid1.plot.density();

# %% [markdown]
# #### 7.3 Autocorrelation

# %%
# Test d'autocolération 
name = ['Lagrange multiplier statistic', 'p-value',
        'f-value', 'f p-value']
for ii,OlS in enumerate(Mco):
    test=sms.acorr_breusch_godfrey(OlS,20)
    
    if test[1] < p_value:
        print(f"L'hypothèse nulle H0 peut être rejetée et l'actif '{cols[ii]}' est autocorrelé!")
        print('')
    else:
        print(f"L'hypothèse nulle H0 ne peut être rejetée et l'actif '{cols[ii]}' n'est pas autocorrelé!")
        print('')
# Out:
# L'hypothèse nulle H0 ne peut être rejetée et l'actif 'CAT' n'est pas autocorrelé!
#
# L'hypothèse nulle H0 ne peut être rejetée et l'actif 'CVX' n'est pas autocorrelé!
#
# L'hypothèse nulle H0 ne peut être rejetée et l'actif 'GS' n'est pas autocorrelé!
#
# L'hypothèse nulle H0 ne peut être rejetée et l'actif 'INTC' n'est pas autocorrelé!
#
# L'hypothèse nulle H0 ne peut être rejetée et l'actif 'JNJ' n'est pas autocorrelé!
#
# L'hypothèse nulle H0 ne peut être rejetée et l'actif 'KO' n'est pas autocorrelé!
#
# L'hypothèse nulle H0 ne peut être rejetée et l'actif 'MCD' n'est pas autocorrelé!
#
# L'hypothèse nulle H0 ne peut être rejetée et l'actif 'V' n'est pas autocorrelé!
#
# L'hypothèse nulle H0 ne peut être rejetée et l'actif 'VZ' n'est pas autocorrelé!
#
# L'hypothèse nulle H0 ne peut être rejetée et l'actif 'WMT' n'est pas autocorrelé!

# %% [markdown]
# #### 7.4 Homoscédasticité

# %%
for i in cols:
    mco = smf.ols(i+'~p_risque',data = Z).fit()
    print(f'== {i} Homoscedasticity Breusch-Pagan Test ==')
    print('')
    print('Breusch-Pagan LM Test Statistic:', np.round(sms.het_breuschpagan(mco.resid, mco.model.exog)[0]))
    print('Breusch-Pagan LM Test P-Value:', np.round(sms.het_breuschpagan(mco.resid, mco.model.exog)[1]))
    print('Breusch-Pagan LM Test F-value:', np.round(sms.het_breuschpagan(mco.resid, mco.model.exog)[2]))
    print('Breusch-Pagan LM Test F P-Value:', np.round(sms.het_breuschpagan(mco.resid, mco.model.exog)[3]))
    p = np.round(sms.het_breuschpagan(mco.resid, mco.model.exog)[1])
    print('----------------')
    if p > 0.05:
        print("Hypothèse H0 retenue (p-value> 5%): Homoscedasticité présente ")
    else:
        print("Hypothèse H0 rejetée (p-value< 5%): pas d'Homoscedasticité présente ")
    print('')
# Out:
# == CAT Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 0.0
# Breusch-Pagan LM Test P-Value: 1.0
# Breusch-Pagan LM Test F-value: 0.0
# Breusch-Pagan LM Test F P-Value: 1.0
# ----------------
# Hypothèse H0 retenue (p-value> 5%): Homoscedasticité présente
#
# == CVX Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 9.0
# Breusch-Pagan LM Test P-Value: 0.0
# Breusch-Pagan LM Test F-value: 10.0
# Breusch-Pagan LM Test F P-Value: 0.0
# ----------------
# Hypothèse H0 rejetée (p-value< 5%): pas d'Homoscedasticité présente
#
# == GS Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 0.0
# Breusch-Pagan LM Test P-Value: 1.0
# Breusch-Pagan LM Test F-value: 0.0
# Breusch-Pagan LM Test F P-Value: 1.0
# ----------------
# Hypothèse H0 retenue (p-value> 5%): Homoscedasticité présente
#
# == INTC Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 1.0
# Breusch-Pagan LM Test P-Value: 0.0
# Breusch-Pagan LM Test F-value: 1.0
# Breusch-Pagan LM Test F P-Value: 0.0
# ----------------
# Hypothèse H0 rejetée (p-value< 5%): pas d'Homoscedasticité présente
#
# == JNJ Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 0.0
# Breusch-Pagan LM Test P-Value: 1.0
# Breusch-Pagan LM Test F-value: 0.0
# Breusch-Pagan LM Test F P-Value: 1.0
# ----------------
# Hypothèse H0 retenue (p-value> 5%): Homoscedasticité présente
#
# == KO Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 2.0
# Breusch-Pagan LM Test P-Value: 0.0
# Breusch-Pagan LM Test F-value: 2.0
# Breusch-Pagan LM Test F P-Value: 0.0
# ----------------
# Hypothèse H0 rejetée (p-value< 5%): pas d'Homoscedasticité présente
#
# == MCD Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 1.0
# Breusch-Pagan LM Test P-Value: 0.0
# Breusch-Pagan LM Test F-value: 1.0
# Breusch-Pagan LM Test F P-Value: 0.0
# ----------------
# Hypothèse H0 rejetée (p-value< 5%): pas d'Homoscedasticité présente
#
# == V Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 0.0
# Breusch-Pagan LM Test P-Value: 1.0
# Breusch-Pagan LM Test F-value: 0.0
# Breusch-Pagan LM Test F P-Value: 1.0
# ----------------
# Hypothèse H0 retenue (p-value> 5%): Homoscedasticité présente
#
# == VZ Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 0.0
# Breusch-Pagan LM Test P-Value: 1.0
# Breusch-Pagan LM Test F-value: 0.0
# Breusch-Pagan LM Test F P-Value: 1.0
# ----------------
# Hypothèse H0 retenue (p-value> 5%): Homoscedasticité présente
#
# == WMT Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 1.0
# Breusch-Pagan LM Test P-Value: 0.0
# Breusch-Pagan LM Test F-value: 1.0
# Breusch-Pagan LM Test F P-Value: 0.0
# ----------------
# Hypothèse H0 rejetée (p-value< 5%): pas d'Homoscedasticité présente

# %% [markdown]
# ### <span style="color:red">8. Vérification de l'Alpha de Jensen </span>

# %%
CAPM = pd.DataFrame(np.column_stack([rsq, alpha, pval]), index = cols, columns = ('R²_adj','Alpha-Jensen(β0)', 'p-value', 'p_risque'))

# %%
CAPM
# Out:
#         R²_adj  Alpha-Jensen(β0)   p-value      p_risque
# CAT   0.410987          0.267980  0.624274  1.274285e-16
# CVX   0.576427         -0.522378  0.198703  7.423393e-26
# GS    0.536060         -0.539107  0.296509  2.605304e-23
# INTC  0.275722          0.346863  0.508163  8.557352e-11
# JNJ   0.388516          0.423595  0.174724  1.437144e-15
# KO    0.316515          0.370789  0.240797  1.964518e-12
# MCD   0.289822          0.745700  0.023286  2.376275e-11
# V     0.452812          1.172377  0.001561  1.091563e-18
# VZ    0.136086          0.688437  0.085125  9.327673e-06
# WMT   0.130670          0.661705  0.110969  1.416031e-05

# %% [markdown]
# **La p-value** des actifs V (Visa) & MCD (Mc Donald's) montrent une forte significativité statistique du p_risque

# %% [markdown]
# ### <span style="color:red">9. Application du Fama French 3 facteurs</span>

# %% [markdown]
# #### 9.1 Mise à jour des variables indépendantes
#
# #### `Les 3 facteurs seront "p_risque" / "SMB" / "HML"`

# %%
X_3 = df[['p_risque','SMB','HML']]

# %% [markdown]
# #### 9.2 Tests de stationnarité de X_3

# %%
X_3.plot()
plt.title('Index')
plt.xlabel('Date')
plt.ylabel('P_RISQUE/SMB/HML')
plt.legend(loc='best', bbox_to_anchor=(1, 0.5))
plt.show();

# %%
#Test de stationnarité 
for i in X_3:
    kpss_results = {}
    print(f'{i}')
    kpss_results = kpss_test(X_3[i])
# Out:
# p_risque
# KPSS statistic: 0.05866430346499228
# p_value: 0.1
# num lags: 13
# Critical values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# Result: the series is stationary
# SMB
# KPSS statistic: 0.07567039670570593
# p_value: 0.1
# num lags: 13
# Critical values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# Result: the series is stationary
# HML
# KPSS statistic: 0.25422227291605304
# p_value: 0.1
# num lags: 13
# Critical values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# Result: the series is stationary
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1875: FutureWarning: The behavior of using nlags=None will change in release 0.13.Currently nlags=None is the same as nlags="legacy", and so a sample-size lag length is used. After the next release, the default will change to be the same as nlags="auto" which uses an automatic lag length selection method. To silence this warning, either use "auto" or "legacy"
#   warnings.warn(msg, FutureWarning)
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %% [markdown]
# #### 9.3 Tests de normalité de X_3

# %%
X_3.plot.density();

# %%
#Test de normalité (Shapiro-Wilk)
#H0 : distribution normale
#HA : pas de distribution normale
p_value = 0.05
for i in X_3 :
    print(i)
    a,b= stats.shapiro(X_3[[i]])
    print ("Statistiques", a, "p_value", b)
    if b < p_value:
        print(f"L'hypothèse nulle H0 peut être rejetée et la série {i} ne présente pas de distribution normale")
    else:
        print(f"L'hypothèse nulle H0 ne peut être rejetée et la série {i} présente une distribution normale")
# Out:
# p_risque
# Statistiques 0.9737986326217651 p_value 0.012762974016368389
# L'hypothèse nulle H0 peut être rejetée et la série p_risque ne présente pas de distribution normale
# SMB
# Statistiques 0.9871628284454346 p_value 0.26498937606811523
# L'hypothèse nulle H0 ne peut être rejetée et la série SMB présente une distribution normale
# HML
# Statistiques 0.9388687610626221 p_value 1.7396876501152292e-05
# L'hypothèse nulle H0 peut être rejetée et la série HML ne présente pas de distribution normale

# %% [markdown]
# #### 9.4 Vérification des hypothèses des moindres carrées OLS

# %%
Z_3 = pd.concat ([y,X_3],1)

# %%
skip = ['p_risque','SMB','HML'] 
cols = Z_3.columns[~Z_3.columns.isin(skip)]
liste3 = []
alpha3 = []
pval3 = []
rsq3 = []
resid3 = []
Mco = []
for i in cols:
    mco = smf.ols(i+'~p_risque+SMB+HML',data = Z_3).fit()
    liste3.append(mco.summary())
    alpha3.append(mco.params.loc['Intercept'])
    pval3.append(mco.pvalues)
    rsq3.append(mco.rsquared_adj)
    resid3.append(sum(mco.resid))
    Mco.append(mco)

# %%
#Résultats de la régression
for l_3 in liste3:
    print(f'{l_3}\n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CAT   R-squared:                       0.426
# Model:                            OLS   Adj. R-squared:                  0.412
# Method:                 Least Squares   F-statistic:                     31.12
# Date:                Fri, 04 Jun 2021   Prob (F-statistic):           4.02e-15
# Time:                        19:25:00   Log-Likelihood:                -416.65
# No. Observations:                 130   AIC:                             841.3
# Df Residuals:                     126   BIC:                             852.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3848      0.556      0.692      0.490      -0.716       1.486
# p_risque       1.2673      0.133      9.526      0.000       1.004       1.531
# SMB           -0.2989      0.219     -1.368      0.174      -0.731       0.134
# HML            0.2189      0.215      1.020      0.310      -0.206       0.644
# ==============================================================================
# Omnibus:                        0.016   Durbin-Watson:                   2.224
# Prob(Omnibus):                  0.992   Jarque-Bera (JB):                0.113
# Skew:                           0.021   Prob(JB):                        0.945
# Kurtosis:                       2.861   Cond. No.                         4.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CVX   R-squared:                       0.583
# Model:                            OLS   Adj. R-squared:                  0.574
# Method:                 Least Squares   F-statistic:                     58.83
# Date:                Fri, 04 Jun 2021   Prob (F-statistic):           7.57e-24
# Time:                        19:25:00   Log-Likelihood:                -378.20
# No. Observations:                 130   AIC:                             764.4
# Df Residuals:                     126   BIC:                             775.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5171      0.414     -1.249      0.214      -1.336       0.302
# p_risque       1.3121      0.099     13.258      0.000       1.116       1.508
# SMB           -0.1633      0.163     -1.004      0.317      -0.485       0.158
# HML            0.0038      0.160      0.024      0.981      -0.312       0.320
# ==============================================================================
# Omnibus:                        0.746   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.688   Jarque-Bera (JB):                0.369
# Skew:                           0.057   Prob(JB):                        0.832
# Kurtosis:                       3.235   Cond. No.                         4.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     GS   R-squared:                       0.543
# Model:                            OLS   Adj. R-squared:                  0.532
# Method:                 Least Squares   F-statistic:                     49.90
# Date:                Fri, 04 Jun 2021   Prob (F-statistic):           2.51e-21
# Time:                        19:25:00   Log-Likelihood:                -409.58
# No. Observations:                 130   AIC:                             827.2
# Df Residuals:                     126   BIC:                             838.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5542      0.527     -1.052      0.295      -1.597       0.489
# p_risque       1.5305      0.126     12.148      0.000       1.281       1.780
# SMB            0.1928      0.207      0.932      0.353      -0.217       0.602
# HML           -0.0220      0.203     -0.108      0.914      -0.424       0.380
# ==============================================================================
# Omnibus:                        4.807   Durbin-Watson:                   2.063
# Prob(Omnibus):                  0.090   Jarque-Bera (JB):                6.159
# Skew:                           0.132   Prob(JB):                       0.0460
# Kurtosis:                       4.033   Cond. No.                         4.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   INTC   R-squared:                       0.282
# Model:                            OLS   Adj. R-squared:                  0.264
# Method:                 Least Squares   F-statistic:                     16.46
# Date:                Fri, 04 Jun 2021   Prob (F-statistic):           4.38e-09
# Time:                        19:25:00   Log-Likelihood:                -412.15
# No. Observations:                 130   AIC:                             832.3
# Df Residuals:                     126   BIC:                             843.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3672      0.537      0.683      0.496      -0.696       1.431
# p_risque       0.9001      0.128      7.005      0.000       0.646       1.154
# SMB           -0.0156      0.211     -0.074      0.941      -0.433       0.402
# HML            0.0396      0.207      0.191      0.849      -0.371       0.450
# ==============================================================================
# Omnibus:                        5.222   Durbin-Watson:                   1.908
# Prob(Omnibus):                  0.073   Jarque-Bera (JB):                5.900
# Skew:                          -0.247   Prob(JB):                       0.0523
# Kurtosis:                       3.919   Cond. No.                         4.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    JNJ   R-squared:                       0.394
# Model:                            OLS   Adj. R-squared:                  0.379
# Method:                 Least Squares   F-statistic:                     27.26
# Date:                Fri, 04 Jun 2021   Prob (F-statistic):           1.18e-13
# Time:                        19:25:00   Log-Likelihood:                -344.37
# No. Observations:                 130   AIC:                             696.7
# Df Residuals:                     126   BIC:                             708.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4364      0.319      1.368      0.174      -0.195       1.068
# p_risque       0.6883      0.076      9.022      0.000       0.537       0.839
# SMB           -0.0282      0.125     -0.225      0.822      -0.276       0.220
# HML            0.0241      0.123      0.196      0.845      -0.219       0.268
# ==============================================================================
# Omnibus:                        0.466   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.792   Jarque-Bera (JB):                0.609
# Skew:                           0.037   Prob(JB):                        0.737
# Kurtosis:                       2.673   Cond. No.                         4.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     KO   R-squared:                       0.324
# Model:                            OLS   Adj. R-squared:                  0.308
# Method:                 Least Squares   F-statistic:                     20.11
# Date:                Fri, 04 Jun 2021   Prob (F-statistic):           1.03e-10
# Time:                        19:25:00   Log-Likelihood:                -345.99
# No. Observations:                 130   AIC:                             700.0
# Df Residuals:                     126   BIC:                             711.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4071      0.323      1.260      0.210      -0.232       1.046
# p_risque       0.5948      0.077      7.700      0.000       0.442       0.748
# SMB           -0.0061      0.127     -0.048      0.962      -0.257       0.245
# HML            0.0716      0.125      0.575      0.567      -0.175       0.318
# ==============================================================================
# Omnibus:                        5.621   Durbin-Watson:                   2.121
# Prob(Omnibus):                  0.060   Jarque-Bera (JB):                5.645
# Skew:                          -0.509   Prob(JB):                       0.0595
# Kurtosis:                       2.918   Cond. No.                         4.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    MCD   R-squared:                       0.299
# Model:                            OLS   Adj. R-squared:                  0.282
# Method:                 Least Squares   F-statistic:                     17.88
# Date:                Fri, 04 Jun 2021   Prob (F-statistic):           9.94e-10
# Time:                        19:25:00   Log-Likelihood:                -349.98
# No. Observations:                 130   AIC:                             708.0
# Df Residuals:                     126   BIC:                             719.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7858      0.333      2.359      0.020       0.127       1.445
# p_risque       0.5786      0.080      7.263      0.000       0.421       0.736
# SMB           -0.0861      0.131     -0.658      0.512      -0.345       0.173
# HML            0.0759      0.129      0.591      0.556      -0.178       0.330
# ==============================================================================
# Omnibus:                        0.777   Durbin-Watson:                   1.693
# Prob(Omnibus):                  0.678   Jarque-Bera (JB):                0.873
# Skew:                           0.172   Prob(JB):                        0.646
# Kurtosis:                       2.794   Cond. No.                         4.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      V   R-squared:                       0.461
# Model:                            OLS   Adj. R-squared:                  0.448
# Method:                 Least Squares   F-statistic:                     35.94
# Date:                Fri, 04 Jun 2021   Prob (F-statistic):           7.49e-17
# Time:                        19:25:00   Log-Likelihood:                -364.16
# No. Observations:                 130   AIC:                             736.3
# Df Residuals:                     126   BIC:                             747.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.1380      0.372      3.063      0.003       0.403       1.873
# p_risque       0.9158      0.089     10.308      0.000       0.740       1.092
# SMB            0.1416      0.146      0.970      0.334      -0.147       0.430
# HML           -0.0624      0.143     -0.435      0.664      -0.346       0.221
# ==============================================================================
# Omnibus:                        9.726   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               16.720
# Skew:                          -0.298   Prob(JB):                     0.000234
# Kurtosis:                       4.653   Cond. No.                         4.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     VZ   R-squared:                       0.153
# Model:                            OLS   Adj. R-squared:                  0.133
# Method:                 Least Squares   F-statistic:                     7.609
# Date:                Fri, 04 Jun 2021   Prob (F-statistic):           0.000102
# Time:                        19:25:00   Log-Likelihood:                -375.51
# No. Observations:                 130   AIC:                             759.0
# Df Residuals:                     126   BIC:                             770.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7609      0.405      1.877      0.063      -0.041       1.563
# p_risque       0.4392      0.097      4.531      0.000       0.247       0.631
# SMB            0.0726      0.159      0.456      0.649      -0.243       0.388
# HML            0.1464      0.156      0.936      0.351      -0.163       0.456
# ==============================================================================
# Omnibus:                        1.331   Durbin-Watson:                   2.294
# Prob(Omnibus):                  0.514   Jarque-Bera (JB):                1.174
# Skew:                          -0.045   Prob(JB):                        0.556
# Kurtosis:                       2.543   Cond. No.                         4.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    WMT   R-squared:                       0.150
# Model:                            OLS   Adj. R-squared:                  0.130
# Method:                 Least Squares   F-statistic:                     7.406
# Date:                Fri, 04 Jun 2021   Prob (F-statistic):           0.000131
# Time:                        19:25:00   Log-Likelihood:                -380.36
# No. Observations:                 130   AIC:                             768.7
# Df Residuals:                     126   BIC:                             780.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7231      0.421      1.718      0.088      -0.110       1.556
# p_risque       0.4546      0.101      4.518      0.000       0.255       0.654
# SMB           -0.2214      0.165     -1.339      0.183      -0.549       0.106
# HML            0.1124      0.162      0.692      0.490      -0.209       0.434
# ==============================================================================
# Omnibus:                        7.904   Durbin-Watson:                   2.075
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):               14.563
# Skew:                           0.131   Prob(JB):                     0.000688
# Kurtosis:                       4.619   Cond. No.                         4.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
FF3 = pd.DataFrame(np.column_stack([rsq3, alpha3, pval3]), index = cols, columns = ('R²_adj','Alpha-Jensen(β0)', 'p-value', 'p_risque(β1)', 'SMB(β2)', 'HML(β3)'))

# %% [markdown]
# ### <span style="color:red">10. Vérification des hypothèses </span>

# %% [markdown]
# #### 10.1 Test de colinéarité

# %%
def vif_cal(input_data, dependent_col):
    x_vars=input_data.drop([dependent_col], axis=1)
    xvar_names=x_vars.columns
    for i in range(0,xvar_names.shape[0]):
        y=x_vars[xvar_names[i]] 
        x=x_vars[xvar_names.drop(xvar_names[i])]
        rsq=smf.ols(formula="y~x", data=x_vars).fit().rsquared  
        vif=round(1/(1-rsq),2)
        print (xvar_names[i], " VIF = " , vif)

# %%
for col_y in cols:
    print(col_y + ':')
    input = Z_3[[col_y,'p_risque', 'SMB', 'HML']]
    vif_cal(input_data=input , dependent_col= col_y)
    print("-------------------------------")
# Out:
# CAT:
# p_risque  VIF =  1.0
# SMB  VIF =  1.14
# HML  VIF =  1.14
# -------------------------------
# CVX:
# p_risque  VIF =  1.0
# SMB  VIF =  1.14
# HML  VIF =  1.14
# -------------------------------
# GS:
# p_risque  VIF =  1.0
# SMB  VIF =  1.14
# HML  VIF =  1.14
# -------------------------------
# INTC:
# p_risque  VIF =  1.0
# SMB  VIF =  1.14
# HML  VIF =  1.14
# -------------------------------
# JNJ:
# p_risque  VIF =  1.0
# SMB  VIF =  1.14
# HML  VIF =  1.14
# -------------------------------
# KO:
# p_risque  VIF =  1.0
# SMB  VIF =  1.14
# HML  VIF =  1.14
# -------------------------------
# MCD:
# p_risque  VIF =  1.0
# SMB  VIF =  1.14
# HML  VIF =  1.14
# -------------------------------
# V:
# p_risque  VIF =  1.0
# SMB  VIF =  1.14
# HML  VIF =  1.14
# -------------------------------
# VZ:
# p_risque  VIF =  1.0
# SMB  VIF =  1.14
# HML  VIF =  1.14
# -------------------------------
# WMT:
# p_risque  VIF =  1.0
# SMB  VIF =  1.14
# HML  VIF =  1.14
# -------------------------------

# %% [markdown]
# #### 10.2 Calcul du Biais

# %%
resid3=pd.DataFrame(resid3, index = cols, columns = ['Biais'])
resid3 /= len(y)
resid3
# Out:
#              Biais
# CAT  -3.962642e-16
# CVX  -3.689357e-16
# GS   -5.055785e-16
# INTC -1.332268e-16
# JNJ   2.186285e-16
# KO    0.000000e+00
# MCD  -3.757678e-17
# V     4.372571e-16
# VZ    1.298107e-16
# WMT  -1.229786e-16

# %%
resid3.plot.density();

# %% [markdown]
# #### 10.3 Autocorrelation

# %%
# Test d'autocolération 
name = ['Lagrange multiplier statistic', 'p-value',
        'f-value', 'f p-value']
for ii,OlS in enumerate(Mco):
    test=sms.acorr_breusch_godfrey(OlS,20)
    
    if test[1] < p_value:
        print(f"L'hypothèse nulle H0 peut être rejetée et l'actif {cols[ii]} est autocorrelé!")
        print("----------")
    else:
        print(f"L'hypothèse nulle H0 ne peut être rejetée et l'actif {cols[ii]} n'est pas autocorrelé!" )
        print("----------")
# Out:
# L'hypothèse nulle H0 ne peut être rejetée et l'actif CAT n'est pas autocorrelé!
# ----------
# L'hypothèse nulle H0 peut être rejetée et l'actif CVX est autocorrelé!
# ----------
# L'hypothèse nulle H0 ne peut être rejetée et l'actif GS n'est pas autocorrelé!
# ----------
# L'hypothèse nulle H0 ne peut être rejetée et l'actif INTC n'est pas autocorrelé!
# ----------
# L'hypothèse nulle H0 ne peut être rejetée et l'actif JNJ n'est pas autocorrelé!
# ----------
# L'hypothèse nulle H0 ne peut être rejetée et l'actif KO n'est pas autocorrelé!
# ----------
# L'hypothèse nulle H0 ne peut être rejetée et l'actif MCD n'est pas autocorrelé!
# ----------
# L'hypothèse nulle H0 ne peut être rejetée et l'actif V n'est pas autocorrelé!
# ----------
# L'hypothèse nulle H0 ne peut être rejetée et l'actif VZ n'est pas autocorrelé!
# ----------
# L'hypothèse nulle H0 ne peut être rejetée et l'actif WMT n'est pas autocorrelé!
# ----------

# %% [markdown]
# #### 10.4 Homoscédasticité

# %%
for i in cols:
    mco = smf.ols(i+'~p_risque+SMB+HML',data = Z_3).fit()
    print(f'== {i} Homoscedasticity Breusch-Pagan Test ==')
    print('')
    print('Breusch-Pagan LM Test Statistic:', np.round(sms.het_breuschpagan(mco.resid, mco.model.exog)[0]))
    print('Breusch-Pagan LM Test P-Value:', np.round(sms.het_breuschpagan(mco.resid, mco.model.exog)[1]))
    print('Breusch-Pagan LM Test F-value:', np.round(sms.het_breuschpagan(mco.resid, mco.model.exog)[2]))
    print('Breusch-Pagan LM Test F P-Value:', np.round(sms.het_breuschpagan(mco.resid, mco.model.exog)[3]))
    p = np.round(sms.het_breuschpagan(mco.resid, mco.model.exog)[1])
    print('----------------')
    if p > 0.05:
        print("Hypothèse H0 retenue (p-value> 5%): Homoscedasticité présente ")
    else:
        print("Hypothèse H0 rejetée (p-value< 5%): pas d'Homoscedasticité présente ")
    print('')
# Out:
# == CAT Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 1.0
# Breusch-Pagan LM Test P-Value: 1.0
# Breusch-Pagan LM Test F-value: 0.0
# Breusch-Pagan LM Test F P-Value: 1.0
# ----------------
# Hypothèse H0 retenue (p-value> 5%): Homoscedasticité présente
#
# == CVX Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 20.0
# Breusch-Pagan LM Test P-Value: 0.0
# Breusch-Pagan LM Test F-value: 8.0
# Breusch-Pagan LM Test F P-Value: 0.0
# ----------------
# Hypothèse H0 rejetée (p-value< 5%): pas d'Homoscedasticité présente
#
# == GS Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 0.0
# Breusch-Pagan LM Test P-Value: 1.0
# Breusch-Pagan LM Test F-value: 0.0
# Breusch-Pagan LM Test F P-Value: 1.0
# ----------------
# Hypothèse H0 retenue (p-value> 5%): Homoscedasticité présente
#
# == INTC Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 1.0
# Breusch-Pagan LM Test P-Value: 1.0
# Breusch-Pagan LM Test F-value: 0.0
# Breusch-Pagan LM Test F P-Value: 1.0
# ----------------
# Hypothèse H0 retenue (p-value> 5%): Homoscedasticité présente
#
# == JNJ Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 5.0
# Breusch-Pagan LM Test P-Value: 0.0
# Breusch-Pagan LM Test F-value: 2.0
# Breusch-Pagan LM Test F P-Value: 0.0
# ----------------
# Hypothèse H0 rejetée (p-value< 5%): pas d'Homoscedasticité présente
#
# == KO Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 3.0
# Breusch-Pagan LM Test P-Value: 0.0
# Breusch-Pagan LM Test F-value: 1.0
# Breusch-Pagan LM Test F P-Value: 0.0
# ----------------
# Hypothèse H0 rejetée (p-value< 5%): pas d'Homoscedasticité présente
#
# == MCD Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 10.0
# Breusch-Pagan LM Test P-Value: 0.0
# Breusch-Pagan LM Test F-value: 4.0
# Breusch-Pagan LM Test F P-Value: 0.0
# ----------------
# Hypothèse H0 rejetée (p-value< 5%): pas d'Homoscedasticité présente
#
# == V Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 1.0
# Breusch-Pagan LM Test P-Value: 1.0
# Breusch-Pagan LM Test F-value: 0.0
# Breusch-Pagan LM Test F P-Value: 1.0
# ----------------
# Hypothèse H0 retenue (p-value> 5%): Homoscedasticité présente
#
# == VZ Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 1.0
# Breusch-Pagan LM Test P-Value: 1.0
# Breusch-Pagan LM Test F-value: 0.0
# Breusch-Pagan LM Test F P-Value: 1.0
# ----------------
# Hypothèse H0 retenue (p-value> 5%): Homoscedasticité présente
#
# == WMT Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 6.0
# Breusch-Pagan LM Test P-Value: 0.0
# Breusch-Pagan LM Test F-value: 2.0
# Breusch-Pagan LM Test F P-Value: 0.0
# ----------------
# Hypothèse H0 rejetée (p-value< 5%): pas d'Homoscedasticité présente

# %% [markdown]
# ### <span style="color:red">11. Application du Fama French 5 facteurs</span>

# %% [markdown]
# #### 11.1 Mise à jour des variables indépendantes
#
# #### `Les 5 facteurs seront "p_risque" / "SMB" / "HML" / "RMW" / "CMA"`

# %%
X_5 = df[['p_risque','SMB','HML','RMW','CMA']]

# %% [markdown]
# #### 11.2 Tests de stationnarité de X_5

# %%
# Séparation des plots à différentes échelles

fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('RMW / CMA')
ax1.plot(X_5.index, X_5['RMW'], color = 'red', label = 'RMW')
ax1.legend()
ax2.plot(X_5.index, X_5['CMA'], color = 'green',label = 'CMA')
ax2.legend()
plt.show();

# %%
#Test de stationnarité 
for i in X_5[['RMW','CMA']]:
    kpss_results = {}
    print(f'{i}')
    kpss_results = kpss_test(X_5[i])
# Out:
# RMW
# KPSS statistic: 0.12021398416865334
# p_value: 0.1
# num lags: 13
# Critical values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# Result: the series is stationary
# CMA
# KPSS statistic: 0.255178411030314
# p_value: 0.1
# num lags: 13
# Critical values:
#  10% : 0.347
#  5% : 0.463
#  2.5% : 0.574
#  1% : 0.739
# Result: the series is stationary
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1875: FutureWarning: The behavior of using nlags=None will change in release 0.13.Currently nlags=None is the same as nlags="legacy", and so a sample-size lag length is used. After the next release, the default will change to be the same as nlags="auto" which uses an automatic lag length selection method. To silence this warning, either use "auto" or "legacy"
#   warnings.warn(msg, FutureWarning)
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# C:\Users\eloue\AppData\Roaming\Python\Python38\site-packages\statsmodels\tsa\stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %% [markdown]
# #### 11.3 Tests de normalité de X_5

# %%
X_5['RMW'].plot.density();

# %%
X_5['CMA'].plot.density();

# %% [markdown]
# #### 11.4 Vérification des hypothèses des moindres carrées OLS

# %%
Z_5 = pd.concat ([y,X_5],1)

# %%
skip = ['p_risque','SMB','HML','RMW','CMA'] 
cols = Z_5.columns[~Z_5.columns.isin(skip)]
liste5 = []
alpha5 = []
pval5 = []
rsq5 = []
resid5 = []
Mco = []
for i in cols:
    mco = smf.ols(i+'~p_risque+SMB+HML+RMW+CMA',data = Z_5).fit()
    liste5.append(mco.summary())
    alpha5.append(mco.params.loc['Intercept'])
    pval5.append(mco.pvalues)
    rsq5.append(mco.rsquared_adj)
    resid5.append(sum(mco.resid))
    Mco.append(mco)

# %%
FF5 = pd.DataFrame(np.column_stack([rsq5, alpha5, pval5]), index = cols, columns = ('R²_adj','Alpha-Jensen (β0)', 'p-value', 'p_risque(β1)', 'SMB(β2)', 'HML(β3)', 'RMW(β4)','CMA(β5)'))

# %% [markdown]
# ### <span style="color:red">12. Vérification des hypothèses </span>

# %% [markdown]
# #### 12.1 Test de colinéarité

# %%
for col_y in cols:
    print(col_y + ':')
    input = Z_5[[col_y,'p_risque','SMB','HML','RMW','CMA']]
    vif_cal(input_data=input , dependent_col= col_y)
    print("--------------")
# Out:
# CAT:
# p_risque  VIF =  1.01
# SMB  VIF =  1.35
# HML  VIF =  1.6
# RMW  VIF =  1.18
# CMA  VIF =  1.42
# --------------
# CVX:
# p_risque  VIF =  1.01
# SMB  VIF =  1.35
# HML  VIF =  1.6
# RMW  VIF =  1.18
# CMA  VIF =  1.42
# --------------
# GS:
# p_risque  VIF =  1.01
# SMB  VIF =  1.35
# HML  VIF =  1.6
# RMW  VIF =  1.18
# CMA  VIF =  1.42
# --------------
# INTC:
# p_risque  VIF =  1.01
# SMB  VIF =  1.35
# HML  VIF =  1.6
# RMW  VIF =  1.18
# CMA  VIF =  1.42
# --------------
# JNJ:
# p_risque  VIF =  1.01
# SMB  VIF =  1.35
# HML  VIF =  1.6
# RMW  VIF =  1.18
# CMA  VIF =  1.42
# --------------
# KO:
# p_risque  VIF =  1.01
# SMB  VIF =  1.35
# HML  VIF =  1.6
# RMW  VIF =  1.18
# CMA  VIF =  1.42
# --------------
# MCD:
# p_risque  VIF =  1.01
# SMB  VIF =  1.35
# HML  VIF =  1.6
# RMW  VIF =  1.18
# CMA  VIF =  1.42
# --------------
# V:
# p_risque  VIF =  1.01
# SMB  VIF =  1.35
# HML  VIF =  1.6
# RMW  VIF =  1.18
# CMA  VIF =  1.42
# --------------
# VZ:
# p_risque  VIF =  1.01
# SMB  VIF =  1.35
# HML  VIF =  1.6
# RMW  VIF =  1.18
# CMA  VIF =  1.42
# --------------
# WMT:
# p_risque  VIF =  1.01
# SMB  VIF =  1.35
# HML  VIF =  1.6
# RMW  VIF =  1.18
# CMA  VIF =  1.42
# --------------

# %% [markdown]
# #### 12.2 Calcul du Biais

# %%
resid5=pd.DataFrame(resid5, index = cols, columns = ['Biais'])
resid5 /= len(y)
resid5
# Out:
#              Biais
# CAT  -4.030964e-16
# CVX  -8.745141e-16
# GS   -7.720320e-16
# INTC -1.673875e-16
# JNJ  -1.366428e-16
# KO   -1.537232e-16
# MCD  -1.434750e-16
# V     4.782499e-17
# VZ   -6.832142e-18
# WMT  -6.148928e-17

# %%
resid5.plot.density();

# %% [markdown]
# #### 12.3 Autocorrelation

# %%
# Test d'autocolération 
name = ['Lagrange multiplier statistic', 'p-value',
        'f-value', 'f p-value']
for ii,OlS in enumerate(Mco):
    test=sms.acorr_breusch_godfrey(OlS,20)
    
    if test[1] < p_value:
        print(f"L'hypothèse nulle H0 peut être rejetée et l'actif {cols[ii]} est autocorrelé!")
        print("")
    else:
        print(f"L'hypothèse nulle H0 ne peut être rejetée et l'actif {cols[ii]} n'est pas autocorrelé!")
        print("")
# Out:
# L'hypothèse nulle H0 ne peut être rejetée et l'actif CAT n'est pas autocorrelé!
#
# L'hypothèse nulle H0 ne peut être rejetée et l'actif CVX n'est pas autocorrelé!
#
# L'hypothèse nulle H0 ne peut être rejetée et l'actif GS n'est pas autocorrelé!
#
# L'hypothèse nulle H0 ne peut être rejetée et l'actif INTC n'est pas autocorrelé!
#
# L'hypothèse nulle H0 ne peut être rejetée et l'actif JNJ n'est pas autocorrelé!
#
# L'hypothèse nulle H0 ne peut être rejetée et l'actif KO n'est pas autocorrelé!
#
# L'hypothèse nulle H0 ne peut être rejetée et l'actif MCD n'est pas autocorrelé!
#
# L'hypothèse nulle H0 ne peut être rejetée et l'actif V n'est pas autocorrelé!
#
# L'hypothèse nulle H0 ne peut être rejetée et l'actif VZ n'est pas autocorrelé!
#
# L'hypothèse nulle H0 ne peut être rejetée et l'actif WMT n'est pas autocorrelé!

# %% [markdown]
# #### 12.4 Homoscédasticité

# %%
for i in cols:
    mco = smf.ols(i+'~p_risque+SMB+HML+RMW+CMA',data = Z_5).fit()
    print(f'== {i} Homoscedasticity Breusch-Pagan Test ==')
    print('')
    print('Breusch-Pagan LM Test Statistic:', np.round(sms.het_breuschpagan(mco.resid, mco.model.exog)[0]))
    print('Breusch-Pagan LM Test P-Value:', np.round(sms.het_breuschpagan(mco.resid, mco.model.exog)[1]))
    print('Breusch-Pagan LM Test F-value:', np.round(sms.het_breuschpagan(mco.resid, mco.model.exog)[2]))
    print('Breusch-Pagan LM Test F P-Value:', np.round(sms.het_breuschpagan(mco.resid, mco.model.exog)[3]))
    p = np.round(sms.het_breuschpagan(mco.resid, mco.model.exog)[1])
    print('----------------')
    if p > 0.05:
        print("Hypothèse H0 retenue (p-value> 5%): Homoscedasticité présente ")
    else:
        print("Hypothèse H0 rejetée (p-value< 5%): pas d'Homoscedasticité présente ")
    print('')
# Out:
# == CAT Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 1.0
# Breusch-Pagan LM Test P-Value: 1.0
# Breusch-Pagan LM Test F-value: 0.0
# Breusch-Pagan LM Test F P-Value: 1.0
# ----------------
# Hypothèse H0 retenue (p-value> 5%): Homoscedasticité présente
#
# == CVX Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 23.0
# Breusch-Pagan LM Test P-Value: 0.0
# Breusch-Pagan LM Test F-value: 5.0
# Breusch-Pagan LM Test F P-Value: 0.0
# ----------------
# Hypothèse H0 rejetée (p-value< 5%): pas d'Homoscedasticité présente
#
# == GS Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 1.0
# Breusch-Pagan LM Test P-Value: 1.0
# Breusch-Pagan LM Test F-value: 0.0
# Breusch-Pagan LM Test F P-Value: 1.0
# ----------------
# Hypothèse H0 retenue (p-value> 5%): Homoscedasticité présente
#
# == INTC Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 7.0
# Breusch-Pagan LM Test P-Value: 0.0
# Breusch-Pagan LM Test F-value: 1.0
# Breusch-Pagan LM Test F P-Value: 0.0
# ----------------
# Hypothèse H0 rejetée (p-value< 5%): pas d'Homoscedasticité présente
#
# == JNJ Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 6.0
# Breusch-Pagan LM Test P-Value: 0.0
# Breusch-Pagan LM Test F-value: 1.0
# Breusch-Pagan LM Test F P-Value: 0.0
# ----------------
# Hypothèse H0 rejetée (p-value< 5%): pas d'Homoscedasticité présente
#
# == KO Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 3.0
# Breusch-Pagan LM Test P-Value: 1.0
# Breusch-Pagan LM Test F-value: 1.0
# Breusch-Pagan LM Test F P-Value: 1.0
# ----------------
# Hypothèse H0 retenue (p-value> 5%): Homoscedasticité présente
#
# == MCD Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 11.0
# Breusch-Pagan LM Test P-Value: 0.0
# Breusch-Pagan LM Test F-value: 2.0
# Breusch-Pagan LM Test F P-Value: 0.0
# ----------------
# Hypothèse H0 rejetée (p-value< 5%): pas d'Homoscedasticité présente
#
# == V Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 3.0
# Breusch-Pagan LM Test P-Value: 1.0
# Breusch-Pagan LM Test F-value: 1.0
# Breusch-Pagan LM Test F P-Value: 1.0
# ----------------
# Hypothèse H0 retenue (p-value> 5%): Homoscedasticité présente
#
# == VZ Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 2.0
# Breusch-Pagan LM Test P-Value: 1.0
# Breusch-Pagan LM Test F-value: 0.0
# Breusch-Pagan LM Test F P-Value: 1.0
# ----------------
# Hypothèse H0 retenue (p-value> 5%): Homoscedasticité présente
#
# == WMT Homoscedasticity Breusch-Pagan Test ==
#
# Breusch-Pagan LM Test Statistic: 7.0
# Breusch-Pagan LM Test P-Value: 0.0
# Breusch-Pagan LM Test F-value: 1.0
# Breusch-Pagan LM Test F P-Value: 0.0
# ----------------
# Hypothèse H0 rejetée (p-value< 5%): pas d'Homoscedasticité présente

# %% [markdown]
# ### <span style="color:red">13.  CAPM / Fama & French 3 / Fama & French 5 </span>

# %%
d = {'CAPM' : CAPM, 'FAMAFRENCH 3' : FF3, 'FAMAFRENCH 5' : FF5}
final = pd.concat([CAPM,FF3,FF5], axis=1, keys=d.keys())

# %%
pd.options.display.max_columns = 20
pd.options.display.max_rows = 20
final
# Out:
#           CAPM                                          FAMAFRENCH 3  \
#         R²_adj Alpha-Jensen(β0)   p-value      p_risque       R²_adj
# CAT   0.410987         0.267980  0.624274  1.274285e-16     0.411922
# CVX   0.576427        -0.522378  0.198703  7.423393e-26     0.573533
# GS    0.536060        -0.539107  0.296509  2.605304e-23     0.532122
# INTC  0.275722         0.346863  0.508163  8.557352e-11     0.264439
# JNJ   0.388516         0.423595  0.174724  1.437144e-15     0.379136
# KO    0.316515         0.370789  0.240797  1.964518e-12     0.307628
# MCD   0.289822         0.745700  0.023286  2.376275e-11     0.281857
# V     0.452812         1.172377  0.001561  1.091563e-18     0.448292
# VZ    0.136086         0.688437  0.085125  9.327673e-06     0.133216
# WMT   0.130670         0.661705  0.110969  1.416031e-05     0.129655
#
#                                                                    \
#      Alpha-Jensen(β0)   p-value  p_risque(β1)   SMB(β2)   HML(β3)
# CAT          0.384755  0.490490  1.560490e-16  0.173872  0.309744
# CVX         -0.517087  0.213868  1.171910e-25  0.317179  0.981116
# GS          -0.554184  0.294915  5.876265e-23  0.353281  0.914194
# INTC         0.367188  0.495701  1.319752e-10  0.941344  0.848850
# JNJ          0.436374  0.173850  2.592362e-15  0.822354  0.844846
# KO           0.407101  0.209954  3.476640e-12  0.961658  0.566525
# MCD          0.785831  0.019872  3.462886e-11  0.511950  0.555821
# V            1.137952  0.002681  1.920798e-18  0.333898  0.664345
# VZ           0.760896  0.062871  1.346687e-05  0.649408  0.351090
# WMT          0.723082  0.088229  1.420642e-05  0.182856  0.489945
#
#      FAMAFRENCH 5                                                      \
#            R²_adj Alpha-Jensen (β0)   p-value  p_risque(β1)   SMB(β2)
# CAT      0.408265          0.410989  0.466449  2.734373e-16  0.103770
# CVX      0.571899         -0.460630  0.272646  4.060164e-25  0.167186
# GS       0.535983         -0.476768  0.369160  1.150013e-22  0.853463
# INTC     0.268571          0.479514  0.376466  3.305811e-10  0.602871
# JNJ      0.395150          0.389142  0.222604  1.478410e-15  0.514097
# KO       0.300715          0.386059  0.240439  3.841861e-12  0.929515
# MCD      0.277110          0.775858  0.022967  5.288258e-11  0.799270
# V        0.440329          1.116700  0.003684  3.507257e-18  0.324696
# VZ       0.121690          0.753647  0.069381  1.714847e-05  0.543383
# WMT      0.164491          0.631358  0.131339  7.165060e-06  0.828237
#
#
#        HML(β3)   RMW(β4)   CMA(β5)
# CAT   0.446143  0.288188  0.767779
# CVX   0.718428  0.268075  0.601716
# GS    0.910227  0.085523  0.842918
# INTC  0.348153  0.369364  0.172385
# JNJ   0.896954  0.022870  0.859966
# KO    0.948360  0.772865  0.413288
# MCD   0.509944  0.317926  0.678673
# V     0.551519  0.858522  0.676945
# VZ    0.386691  0.583562  0.830770
# WMT   0.757114  0.008372  0.800534

# %%
final.plot(y=[(        'CAPM',            'R²_adj'),('FAMAFRENCH 3',            'R²_adj'),('FAMAFRENCH 5',            'R²_adj')], kind="bar");

# %%
final.plot(y=[(        'CAPM',            'p-value'),('FAMAFRENCH 3',            'p-value'),('FAMAFRENCH 5',            'p-value')], kind="bar",color=['darkred', 'gold', 'mediumblue'],title = 'p-value');

# %%
final.plot(y=[(        'CAPM',            'Alpha-Jensen(β0)'),('FAMAFRENCH 3',            'Alpha-Jensen(β0)'),('FAMAFRENCH 5', 'Alpha-Jensen (β0)')], kind="bar",color=['green', 'black', 'red'], title = 'Alpha-Jensen (β0)');

# %% [markdown]
# - Les **R² ajustés** varient du CAPM vers le F&F 5 facteurs
# - Les actifs V (VISA) & MCD (Mc Donald's) ont la plus grande significativité statistique avec une **p-value < 0.05**
# - L'**Alpha de Jensen** pour un actif donné augumente du CAPM vers le FF5
